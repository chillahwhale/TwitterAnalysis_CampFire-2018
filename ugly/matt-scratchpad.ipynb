# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./datasets/df_cleaned.csv')
df.head()
# Out:
#    tweet_count          City                   id  \
# 0         6006    Sacramento  1059959242336145408
# 1         6005    Sacramento  1059959881237782528
# 2         6004    Sacramento  1059960170313342978
# 3          901  Butte County  1059960216891080704
# 4         6003    Sacramento  1059960413637500928
#
#                                           tweet_text  \
# 0  Vote for our future because they are Hopeful f...
# 1  I grew up in a family that celebrated the priv...
# 2  Getting ready for our "Bubbles and Bling" even...
# 3  VOTE do it for the future . . . . . #pmgridcha...
# 4  #ivotedtoday #vote #voteelkgrove #waveofchange...
#
#                    timestamp  \
# 0  2018-11-07 00:02:31+00:00
# 1  2018-11-07 00:05:03+00:00
# 2  2018-11-07 00:06:12+00:00
# 3  2018-11-07 00:06:23+00:00
# 4  2018-11-07 00:07:10+00:00
#
#                                             hashtags        username mentions  \
# ...

# %%
df['City'].value_counts()
# Out:
# Sacramento      5999
# Butte County     341
# Chico, CA        298
# Paradise, CA     284
# Name: City, dtype: int64

# %%
df.dtypes
# Out:
# tweet_count     int64
# City           object
# id              int64
# tweet_text     object
# timestamp      object
# hashtags       object
# username       object
# mentions       object
# rewtweets       int64
# replies         int64
# link           object
# dtype: object

# %%
df.shape
# Out:
# (6922, 11)

# %%
df['tweet_text'][0]
# Out:
# 'Vote for our future because they are Hopeful for what’s to come. @Fair Oaks, California https://www.instagram.com/p/Bp2MN-iHb-R/?utm_source=ig_twitter_share&amp;igshid=1ovil66agh1m3'

# %%
# fire = 
[i for i in df['tweet_text'][i] if i.str.contains(pat='fire', case=False)]
# Out:
# --------------------------------------------------------------
# NameError                    Traceback (most recent call last)
# <ipython-input-9-4737b0b2bfb7> in <module>
#       1 # fire =
# ----> 2 [i for i in df['tweet_text'][i] if i.str.contains(pat='fire', case=False)]
#
# NameError: name 'i' is not defined

# %%
tweet_text = pd.Series(df['tweet_text'])
tweet_text
# Out:
# 0       Vote for our future because they are Hopeful f...
# 1       I grew up in a family that celebrated the priv...
# 2       Getting ready for our "Bubbles and Bling" even...
# 3       VOTE do it for the future . . . . . #pmgridcha...
# 4       #ivotedtoday #vote #voteelkgrove #waveofchange...
#                               ...
# 6917    one of the best things about marrying alexklei...
# 6918                                 #losgrandesdetijuana
# 6919    Lord Farquad Quad Squat Squad @Chico, Californ...
# 6920    Just posted a photo @Plaza De Cesar Chavez htt...
# 6921    #asianribs #friedrice #fallsoffthebone #meltsi...
# Name: tweet_text, Length: 6922, dtype: object

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)
tweet_text.head(500)
# Out:
# /Users/mattburke/anaconda/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
# 0      Vote for our future because they are Hopeful for what’s to come. @Fair Oaks, California https://www.instagram.com/p/Bp2MN-iHb-R/?utm_source=ig_twitter_share&amp;igshid=1ovil66agh1m3
# 1      I grew up in a family that celebrated the privilege of voting. I don’t want to ever take any of it for granted. I’m grateful for this messy, complicated and important freedom we were… https://www.instagram.com/p/Bp27zHBArg0/?utm_source=ig_twitter_share&amp;igshid=x99ebs22pd0e
# ...

# %%
# for tweet in tweet_text[tweet]:
#     if tweet_text[tweet].str.contains(pat='fire'):
#         print(tweet_text[tweet])
# Out:
# --------------------------------------------------------------
# KeyError                     Traceback (most recent call last)
# <ipython-input-23-029669a338b3> in <module>
# ----> 1 for tweet in tweet_text[tweet]:
#       2     if tweet_text[tweet].str.contains(pat='fire'):
#       3         print(tweet_text[tweet])
#
# ~/anaconda/envs/dsi/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/anaconda/envs/dsi/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4402         k = self._convert_scalar_indexer(k, kind="getitem")
#    4403         try:
# -> 4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4405         except KeyError as e1:
# ...

# %%
df.head()
# Out:
#    tweet_count          City                   id  \
# 0  6006         Sacramento    1059959242336145408
# 1  6005         Sacramento    1059959881237782528
# 2  6004         Sacramento    1059960170313342978
# 3  901          Butte County  1059960216891080704
# 4  6003         Sacramento    1059960413637500928
#
#                                                                                                                                                                                                                                                                                 tweet_text  \
# 0  Vote for our future because they are Hopeful for what’s to come. @Fair Oaks, California https://www.instagram.com/p/Bp2MN-iHb-R/?utm_source=ig_twitter_share&amp;igshid=1ovil66agh1m3
# ...

# %%
df[(df['username'].str.contains(pat='fire') == True)]
# Out:
#       tweet_count          City                   id  \
# 1011  694          Chico, CA     1060981501997780992
# 4523  275          Chico, CA     1064346809420537857
# 4705  266          Butte County  1064595323752861697
# 5350  1400         Sacramento    1065315004482764801
# 5823  117          Butte County  1065718729630261254
# 5969  103          Butte County  1065824197665058816
# 6710  188          Sacramento    1066602202775486464
#
#                                                                                                                                                                                                                                                                                     tweet_text  \
# ...

# %%
df[(df['mentions'].str.contains(pat='fire') == True)]
# Out:
#       tweet_count          City                   id  \
# 5823  117          Butte County  1065718729630261254
#
#                                                                                                                                                                                                                                                                                     tweet_text  \
# 5823  As many of us settle in for a family meal, at @montecitofire we reflect on the last year and are Thankful for countless items, not the least of which is our ability to help others. Still… https://www.instagram.com/p/Bqf2oC4F7s-/?utm_source=ig_twitter_share&amp;igshid=eqaxn85webnt
#
#                       timestamp hashtags       username        mentions  \
# 5823  2018-11-22 21:28:39+00:00  NaN      montecitofire  @montecitofire
#
#       rewtweets  replies  \
# 5823  1          1
#
#                                                               link
# ...

# %%
df[(df['tweet_text'][0:].str.contains(pat='fire') == True)]
# Out:
#       tweet_count          City                   id  \
# 499   5561         Sacramento    1060406917963673601
# 550   5514         Sacramento    1060558942093348866
# 575   757          Chico, CA     1060579478177492992
# 593   756          Chico, CA     1060587888654483456
# 597   755          Chico, CA     1060588195333791746
# ...   ...                ...                     ...
# 6763  30           Butte County  1066730858403569664
# 6782  28           Butte County  1066752850011803650
# 6784  27           Butte County  1066755091049279488
# 6835  24           Butte County  1066794739523964928
# 6867  41           Sacramento    1066824060934504448
#
#                                                                                                                                                                                                                                                                                       tweet_text  \
# ...

# %%
df[(df['tweet_text'][0:].str.contains(pat='instagram') == True)]
# Out:
#       tweet_count          City                   id  \
# 0     6006         Sacramento    1059959242336145408
# 1     6005         Sacramento    1059959881237782528
# 2     6004         Sacramento    1059960170313342978
# 3     901          Butte County  1059960216891080704
# 4     6003         Sacramento    1059960413637500928
# ...    ...                ...                    ...
# 6916  5            Sacramento    1066843374756470784
# 6917  4            Sacramento    1066843394205315072
# 6919  2            Sacramento    1066843491555205120
# 6920  1            Sacramento    1066843803686887424
# 6921  0            Sacramento    1066843931114115072
#
#                                                                                                                                                                                                                                                                                      tweet_text  \
# ...
